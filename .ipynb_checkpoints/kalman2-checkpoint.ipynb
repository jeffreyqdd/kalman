# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
'''
a plane is landing assume that
altitude_t = 0.98 * altitude_t-1
'''
#-----input
ALTITUDE_0 = 1000 #assume in meters

#------logic
time_t = [0]
altitude_t = [ALTITUDE_0]

for i in range(1,300+1):
    time_t.append(i)
    altitude_t.append(altitude_t[-1] * 0.98)

plt.plot(time_t, altitude_t)
plt.show()

# %%
'''
assuming our sensor has noise:
observed_t = altitude_t + noise_t
'''

#-----input
#ALTITUDE_0 = 1000 #assume in meters
NOISE = 40 #assume +/- in meters

#------logic
# time_t = [0]
# altitude_t = [ALTITUDE_0]
observed_t = []



for index, real_altitude in enumerate(altitude_t):
    observed_t.append(real_altitude + np.random.uniform(-NOISE, NOISE))

plt.plot(time_t, observed_t)
plt.show()

# %%
'''
let's now make it more generic. 
x_k = a * x_k-1 //current state = changes * previous state
z_k = x_k + v_k //observed state = current state + noise

so if the state has disturbances, we can also add process noise
x_k = a * x_k-1 + w_k //current state = changes * previous state + process noise
z_k = x_k + v_k //observed state = current state + noise
'''

def thing():
    x=1
thing()
#now no dumb outputs

# %%
'''
without process noise
x_k = a * x_k-1 
z_k = x_k + v_k

we can rearrage the 2nd equation:
x_k = z_k - noise //current state = observed state - noise


low g = noisy sensor, high g = good sensor
x_hat_k = x_hat_k-1 + g_k (z_k - x_hat_k-1)

--> our current estimated state = previous estimated state
    + gain(previous observed value - previous estimated state)
'''

#-----input
#ALTITUDE_0 = 1000 #assume in meters
#NOISE = 40 #assume +/- in meters
GAIN = 0.2 # g_k

#------logic
# time_t = [0]
# altitude_t = [ALTITUDE_0]
# observed_t = []
estimated_state_t = [ALTITUDE_0]

for i, observed in enumerate(observed_t):
    if i == 0:
        continue
    predicted = estimated_state_t[-1] + GAIN * (observed - estimated_state_t[-1])
    
    estimated_state_t.append(predicted)
    
plt.scatter(time_t, observed_t, label = "observations", s=1)
plt.plot(time_t, estimated_state_t, label = "estimation")
plt.plot(time_t, altitude_t, label = "real")
plt.show()

# %%
'''
How do we compute gain?

recall that: measurement = actual_state + noise

manufactureres will typically publish sensor error ranges
• +/- r (property of the sensor)

thus, we can compute the gain by
•g_k = p_k-1 / (p_k-1 + r)
•where p_k is prediction error and is computed recursively
    p_k = (1-g_k) * p_k-1
    current prediction error = 
        (1-gain) * previous prediction error
'''


#-----input
#ALTITUDE_0 = 1000 #assume in meters
#NOISE = 40 #assume +/- in meters

#------logic
# time_t = [0]
# altitude_t = [ALTITUDE_0]
# observed_t = []
estimated_state_t = [ALTITUDE_0] #overwrite estimated state w/ new
g_k = [1]
p_k = [10000]


r = np.average(abs(np.array(altitude_t) - np.array(observed_t)))
print(r)

for k, time in enumerate(time_t):
    if k == 0:
        continue
    
    g_k.append( p_k[k-1] / (p_k[k-1] + r) )
    p_k.append( (1-g_k[k]) * p_k[k-1]     )
    
    predicted = estimated_state_t[-1] + g_k[k] * (observed_t[k] - estimated_state_t[-1])
    
    estimated_state_t.append(predicted)

plt.scatter(time_t, observed_t, label = "observations", s=1)
plt.plot(time_t, estimated_state_t, label = "estimation")
plt.plot(time_t, altitude_t, label = "real")
plt.legend()
plt.show()

# for thing in p_k:
#     print(round(thing,2))
for i in range(0, len(g_k)):
    print( f"round: {i},  gain: {round(g_k[i],2)},  prediction error: {round(p_k[i],2)}" )
# Out:
# 10000
# round: 0,  gain: 1,  prediction error: 10000
# round: 1,  gain: 0.5,  prediction error: 5000.0
# round: 2,  gain: 0.33,  prediction error: 3333.33
# round: 3,  gain: 0.25,  prediction error: 2500.0
# round: 4,  gain: 0.2,  prediction error: 2000.0
# round: 5,  gain: 0.17,  prediction error: 1666.67
# round: 6,  gain: 0.14,  prediction error: 1428.57
# round: 7,  gain: 0.12,  prediction error: 1250.0
# round: 8,  gain: 0.11,  prediction error: 1111.11
# round: 9,  gain: 0.1,  prediction error: 1000.0
# round: 10,  gain: 0.09,  prediction error: 909.09
# round: 11,  gain: 0.08,  prediction error: 833.33
# round: 12,  gain: 0.08,  prediction error: 769.23
# round: 13,  gain: 0.07,  prediction error: 714.29
# round: 14,  gain: 0.07,  prediction error: 666.67
# round: 15,  gain: 0.06,  prediction error: 625.0
# round: 16,  gain: 0.06,  prediction error: 588.24
# round: 17,  gain: 0.06,  prediction error: 555.56
# round: 18,  gain: 0.05,  prediction error: 526.32
# round: 19,  gain: 0.05,  prediction error: 500.0
# round: 20,  gain: 0.05,  prediction error: 476.19
# round: 21,  gain: 0.05,  prediction error: 454.55
# round: 22,  gain: 0.04,  prediction error: 434.78
# round: 23,  gain: 0.04,  prediction error: 416.67
# round: 24,  gain: 0.04,  prediction error: 400.0
# round: 25,  gain: 0.04,  prediction error: 384.62
# round: 26,  gain: 0.04,  prediction error: 370.37
# round: 27,  gain: 0.04,  prediction error: 357.14
# round: 28,  gain: 0.03,  prediction error: 344.83
# round: 29,  gain: 0.03,  prediction error: 333.33
# round: 30,  gain: 0.03,  prediction error: 322.58
# round: 31,  gain: 0.03,  prediction error: 312.5
# round: 32,  gain: 0.03,  prediction error: 303.03
# round: 33,  gain: 0.03,  prediction error: 294.12
# round: 34,  gain: 0.03,  prediction error: 285.71
# round: 35,  gain: 0.03,  prediction error: 277.78
# round: 36,  gain: 0.03,  prediction error: 270.27
# round: 37,  gain: 0.03,  prediction error: 263.16
# round: 38,  gain: 0.03,  prediction error: 256.41
# round: 39,  gain: 0.03,  prediction error: 250.0
# round: 40,  gain: 0.02,  prediction error: 243.9
# round: 41,  gain: 0.02,  prediction error: 238.1
# round: 42,  gain: 0.02,  prediction error: 232.56
# round: 43,  gain: 0.02,  prediction error: 227.27
# round: 44,  gain: 0.02,  prediction error: 222.22
# round: 45,  gain: 0.02,  prediction error: 217.39
# round: 46,  gain: 0.02,  prediction error: 212.77
# round: 47,  gain: 0.02,  prediction error: 208.33
# round: 48,  gain: 0.02,  prediction error: 204.08
# round: 49,  gain: 0.02,  prediction error: 200.0
# round: 50,  gain: 0.02,  prediction error: 196.08
# round: 51,  gain: 0.02,  prediction error: 192.31
# round: 52,  gain: 0.02,  prediction error: 188.68
# round: 53,  gain: 0.02,  prediction error: 185.19
# round: 54,  gain: 0.02,  prediction error: 181.82
# round: 55,  gain: 0.02,  prediction error: 178.57
# round: 56,  gain: 0.02,  prediction error: 175.44
# round: 57,  gain: 0.02,  prediction error: 172.41
# round: 58,  gain: 0.02,  prediction error: 169.49
# round: 59,  gain: 0.02,  prediction error: 166.67
# round: 60,  gain: 0.02,  prediction error: 163.93
# round: 61,  gain: 0.02,  prediction error: 161.29
# round: 62,  gain: 0.02,  prediction error: 158.73
# round: 63,  gain: 0.02,  prediction error: 156.25
# round: 64,  gain: 0.02,  prediction error: 153.85
# round: 65,  gain: 0.02,  prediction error: 151.52
# round: 66,  gain: 0.01,  prediction error: 149.25
# round: 67,  gain: 0.01,  prediction error: 147.06
# round: 68,  gain: 0.01,  prediction error: 144.93
# round: 69,  gain: 0.01,  prediction error: 142.86
# round: 70,  gain: 0.01,  prediction error: 140.85
# round: 71,  gain: 0.01,  prediction error: 138.89
# round: 72,  gain: 0.01,  prediction error: 136.99
# round: 73,  gain: 0.01,  prediction error: 135.14
# round: 74,  gain: 0.01,  prediction error: 133.33
# round: 75,  gain: 0.01,  prediction error: 131.58
# round: 76,  gain: 0.01,  prediction error: 129.87
# round: 77,  gain: 0.01,  prediction error: 128.21
# round: 78,  gain: 0.01,  prediction error: 126.58
# round: 79,  gain: 0.01,  prediction error: 125.0
# round: 80,  gain: 0.01,  prediction error: 123.46
# round: 81,  gain: 0.01,  prediction error: 121.95
# round: 82,  gain: 0.01,  prediction error: 120.48
# round: 83,  gain: 0.01,  prediction error: 119.05
# round: 84,  gain: 0.01,  prediction error: 117.65
# round: 85,  gain: 0.01,  prediction error: 116.28
# round: 86,  gain: 0.01,  prediction error: 114.94
# round: 87,  gain: 0.01,  prediction error: 113.64
# round: 88,  gain: 0.01,  prediction error: 112.36
# round: 89,  gain: 0.01,  prediction error: 111.11
# round: 90,  gain: 0.01,  prediction error: 109.89
# round: 91,  gain: 0.01,  prediction error: 108.7
# round: 92,  gain: 0.01,  prediction error: 107.53
# round: 93,  gain: 0.01,  prediction error: 106.38
# round: 94,  gain: 0.01,  prediction error: 105.26
# round: 95,  gain: 0.01,  prediction error: 104.17
# round: 96,  gain: 0.01,  prediction error: 103.09
# round: 97,  gain: 0.01,  prediction error: 102.04
# round: 98,  gain: 0.01,  prediction error: 101.01
# round: 99,  gain: 0.01,  prediction error: 100.0
# round: 100,  gain: 0.01,  prediction error: 99.01
# round: 101,  gain: 0.01,  prediction error: 98.04
# round: 102,  gain: 0.01,  prediction error: 97.09
# round: 103,  gain: 0.01,  prediction error: 96.15
# round: 104,  gain: 0.01,  prediction error: 95.24
# round: 105,  gain: 0.01,  prediction error: 94.34
# round: 106,  gain: 0.01,  prediction error: 93.46
# round: 107,  gain: 0.01,  prediction error: 92.59
# round: 108,  gain: 0.01,  prediction error: 91.74
# round: 109,  gain: 0.01,  prediction error: 90.91
# round: 110,  gain: 0.01,  prediction error: 90.09
# round: 111,  gain: 0.01,  prediction error: 89.29
# round: 112,  gain: 0.01,  prediction error: 88.5
# round: 113,  gain: 0.01,  prediction error: 87.72
# round: 114,  gain: 0.01,  prediction error: 86.96
# round: 115,  gain: 0.01,  prediction error: 86.21
# round: 116,  gain: 0.01,  prediction error: 85.47
# round: 117,  gain: 0.01,  prediction error: 84.75
# round: 118,  gain: 0.01,  prediction error: 84.03
# round: 119,  gain: 0.01,  prediction error: 83.33
# round: 120,  gain: 0.01,  prediction error: 82.64
# round: 121,  gain: 0.01,  prediction error: 81.97
# round: 122,  gain: 0.01,  prediction error: 81.3
# round: 123,  gain: 0.01,  prediction error: 80.65
# round: 124,  gain: 0.01,  prediction error: 80.0
# round: 125,  gain: 0.01,  prediction error: 79.37
# round: 126,  gain: 0.01,  prediction error: 78.74
# round: 127,  gain: 0.01,  prediction error: 78.13
# round: 128,  gain: 0.01,  prediction error: 77.52
# round: 129,  gain: 0.01,  prediction error: 76.92
# round: 130,  gain: 0.01,  prediction error: 76.34
# round: 131,  gain: 0.01,  prediction error: 75.76
# round: 132,  gain: 0.01,  prediction error: 75.19
# round: 133,  gain: 0.01,  prediction error: 74.63
# round: 134,  gain: 0.01,  prediction error: 74.07
# round: 135,  gain: 0.01,  prediction error: 73.53
# round: 136,  gain: 0.01,  prediction error: 72.99
# round: 137,  gain: 0.01,  prediction error: 72.46
# round: 138,  gain: 0.01,  prediction error: 71.94
# round: 139,  gain: 0.01,  prediction error: 71.43
# round: 140,  gain: 0.01,  prediction error: 70.92
# round: 141,  gain: 0.01,  prediction error: 70.42
# round: 142,  gain: 0.01,  prediction error: 69.93
# round: 143,  gain: 0.01,  prediction error: 69.44
# round: 144,  gain: 0.01,  prediction error: 68.97
# round: 145,  gain: 0.01,  prediction error: 68.49
# round: 146,  gain: 0.01,  prediction error: 68.03
# round: 147,  gain: 0.01,  prediction error: 67.57
# round: 148,  gain: 0.01,  prediction error: 67.11
# round: 149,  gain: 0.01,  prediction error: 66.67
# round: 150,  gain: 0.01,  prediction error: 66.23
# round: 151,  gain: 0.01,  prediction error: 65.79
# round: 152,  gain: 0.01,  prediction error: 65.36
# round: 153,  gain: 0.01,  prediction error: 64.94
# round: 154,  gain: 0.01,  prediction error: 64.52
# round: 155,  gain: 0.01,  prediction error: 64.1
# round: 156,  gain: 0.01,  prediction error: 63.69
# round: 157,  gain: 0.01,  prediction error: 63.29
# round: 158,  gain: 0.01,  prediction error: 62.89
# round: 159,  gain: 0.01,  prediction error: 62.5
# round: 160,  gain: 0.01,  prediction error: 62.11
# round: 161,  gain: 0.01,  prediction error: 61.73
# round: 162,  gain: 0.01,  prediction error: 61.35
# round: 163,  gain: 0.01,  prediction error: 60.98
# round: 164,  gain: 0.01,  prediction error: 60.61
# round: 165,  gain: 0.01,  prediction error: 60.24
# round: 166,  gain: 0.01,  prediction error: 59.88
# round: 167,  gain: 0.01,  prediction error: 59.52
# round: 168,  gain: 0.01,  prediction error: 59.17
# round: 169,  gain: 0.01,  prediction error: 58.82
# round: 170,  gain: 0.01,  prediction error: 58.48
# round: 171,  gain: 0.01,  prediction error: 58.14
# round: 172,  gain: 0.01,  prediction error: 57.8
# round: 173,  gain: 0.01,  prediction error: 57.47
# round: 174,  gain: 0.01,  prediction error: 57.14
# round: 175,  gain: 0.01,  prediction error: 56.82
# round: 176,  gain: 0.01,  prediction error: 56.5
# round: 177,  gain: 0.01,  prediction error: 56.18
# round: 178,  gain: 0.01,  prediction error: 55.87
# round: 179,  gain: 0.01,  prediction error: 55.56
# round: 180,  gain: 0.01,  prediction error: 55.25
# round: 181,  gain: 0.01,  prediction error: 54.95
# round: 182,  gain: 0.01,  prediction error: 54.64
# round: 183,  gain: 0.01,  prediction error: 54.35
# round: 184,  gain: 0.01,  prediction error: 54.05
# round: 185,  gain: 0.01,  prediction error: 53.76
# round: 186,  gain: 0.01,  prediction error: 53.48
# round: 187,  gain: 0.01,  prediction error: 53.19
# round: 188,  gain: 0.01,  prediction error: 52.91
# round: 189,  gain: 0.01,  prediction error: 52.63
# round: 190,  gain: 0.01,  prediction error: 52.36
# round: 191,  gain: 0.01,  prediction error: 52.08
# round: 192,  gain: 0.01,  prediction error: 51.81
# round: 193,  gain: 0.01,  prediction error: 51.55
# round: 194,  gain: 0.01,  prediction error: 51.28
# round: 195,  gain: 0.01,  prediction error: 51.02
# round: 196,  gain: 0.01,  prediction error: 50.76
# round: 197,  gain: 0.01,  prediction error: 50.51
# round: 198,  gain: 0.01,  prediction error: 50.25
# round: 199,  gain: 0.0,  prediction error: 50.0
# round: 200,  gain: 0.0,  prediction error: 49.75
# round: 201,  gain: 0.0,  prediction error: 49.5
# round: 202,  gain: 0.0,  prediction error: 49.26
# round: 203,  gain: 0.0,  prediction error: 49.02
# round: 204,  gain: 0.0,  prediction error: 48.78
# round: 205,  gain: 0.0,  prediction error: 48.54
# round: 206,  gain: 0.0,  prediction error: 48.31
# round: 207,  gain: 0.0,  prediction error: 48.08
# round: 208,  gain: 0.0,  prediction error: 47.85
# round: 209,  gain: 0.0,  prediction error: 47.62
# round: 210,  gain: 0.0,  prediction error: 47.39
# round: 211,  gain: 0.0,  prediction error: 47.17
# round: 212,  gain: 0.0,  prediction error: 46.95
# round: 213,  gain: 0.0,  prediction error: 46.73
# round: 214,  gain: 0.0,  prediction error: 46.51
# round: 215,  gain: 0.0,  prediction error: 46.3
# round: 216,  gain: 0.0,  prediction error: 46.08
# round: 217,  gain: 0.0,  prediction error: 45.87
# round: 218,  gain: 0.0,  prediction error: 45.66
# round: 219,  gain: 0.0,  prediction error: 45.45
# round: 220,  gain: 0.0,  prediction error: 45.25
# round: 221,  gain: 0.0,  prediction error: 45.05
# round: 222,  gain: 0.0,  prediction error: 44.84
# round: 223,  gain: 0.0,  prediction error: 44.64
# round: 224,  gain: 0.0,  prediction error: 44.44
# round: 225,  gain: 0.0,  prediction error: 44.25
# round: 226,  gain: 0.0,  prediction error: 44.05
# round: 227,  gain: 0.0,  prediction error: 43.86
# round: 228,  gain: 0.0,  prediction error: 43.67
# round: 229,  gain: 0.0,  prediction error: 43.48
# round: 230,  gain: 0.0,  prediction error: 43.29
# round: 231,  gain: 0.0,  prediction error: 43.1
# round: 232,  gain: 0.0,  prediction error: 42.92
# round: 233,  gain: 0.0,  prediction error: 42.74
# round: 234,  gain: 0.0,  prediction error: 42.55
# round: 235,  gain: 0.0,  prediction error: 42.37
# round: 236,  gain: 0.0,  prediction error: 42.19
# round: 237,  gain: 0.0,  prediction error: 42.02
# round: 238,  gain: 0.0,  prediction error: 41.84
# round: 239,  gain: 0.0,  prediction error: 41.67
# round: 240,  gain: 0.0,  prediction error: 41.49
# round: 241,  gain: 0.0,  prediction error: 41.32
# round: 242,  gain: 0.0,  prediction error: 41.15
# round: 243,  gain: 0.0,  prediction error: 40.98
# round: 244,  gain: 0.0,  prediction error: 40.82
# round: 245,  gain: 0.0,  prediction error: 40.65
# round: 246,  gain: 0.0,  prediction error: 40.49
# round: 247,  gain: 0.0,  prediction error: 40.32
# round: 248,  gain: 0.0,  prediction error: 40.16
# round: 249,  gain: 0.0,  prediction error: 40.0
# round: 250,  gain: 0.0,  prediction error: 39.84
# round: 251,  gain: 0.0,  prediction error: 39.68
# round: 252,  gain: 0.0,  prediction error: 39.53
# round: 253,  gain: 0.0,  prediction error: 39.37
# round: 254,  gain: 0.0,  prediction error: 39.22
# round: 255,  gain: 0.0,  prediction error: 39.06
# round: 256,  gain: 0.0,  prediction error: 38.91
# round: 257,  gain: 0.0,  prediction error: 38.76
# round: 258,  gain: 0.0,  prediction error: 38.61
# round: 259,  gain: 0.0,  prediction error: 38.46
# round: 260,  gain: 0.0,  prediction error: 38.31
# round: 261,  gain: 0.0,  prediction error: 38.17
# round: 262,  gain: 0.0,  prediction error: 38.02
# round: 263,  gain: 0.0,  prediction error: 37.88
# round: 264,  gain: 0.0,  prediction error: 37.74
# round: 265,  gain: 0.0,  prediction error: 37.59
# round: 266,  gain: 0.0,  prediction error: 37.45
# round: 267,  gain: 0.0,  prediction error: 37.31
# round: 268,  gain: 0.0,  prediction error: 37.17
# round: 269,  gain: 0.0,  prediction error: 37.04
# round: 270,  gain: 0.0,  prediction error: 36.9
# round: 271,  gain: 0.0,  prediction error: 36.76
# round: 272,  gain: 0.0,  prediction error: 36.63
# round: 273,  gain: 0.0,  prediction error: 36.5
# round: 274,  gain: 0.0,  prediction error: 36.36
# round: 275,  gain: 0.0,  prediction error: 36.23
# round: 276,  gain: 0.0,  prediction error: 36.1
# round: 277,  gain: 0.0,  prediction error: 35.97
# round: 278,  gain: 0.0,  prediction error: 35.84
# round: 279,  gain: 0.0,  prediction error: 35.71
# round: 280,  gain: 0.0,  prediction error: 35.59
# round: 281,  gain: 0.0,  prediction error: 35.46
# round: 282,  gain: 0.0,  prediction error: 35.34
# round: 283,  gain: 0.0,  prediction error: 35.21
# round: 284,  gain: 0.0,  prediction error: 35.09
# round: 285,  gain: 0.0,  prediction error: 34.97
# round: 286,  gain: 0.0,  prediction error: 34.84
# round: 287,  gain: 0.0,  prediction error: 34.72
# round: 288,  gain: 0.0,  prediction error: 34.6
# round: 289,  gain: 0.0,  prediction error: 34.48
# round: 290,  gain: 0.0,  prediction error: 34.36
# round: 291,  gain: 0.0,  prediction error: 34.25
# round: 292,  gain: 0.0,  prediction error: 34.13
# round: 293,  gain: 0.0,  prediction error: 34.01
# round: 294,  gain: 0.0,  prediction error: 33.9
# round: 295,  gain: 0.0,  prediction error: 33.78
# round: 296,  gain: 0.0,  prediction error: 33.67
# round: 297,  gain: 0.0,  prediction error: 33.56
# round: 298,  gain: 0.0,  prediction error: 33.44
# round: 299,  gain: 0.0,  prediction error: 33.33
# round: 300,  gain: 0.0,  prediction error: 33.22
