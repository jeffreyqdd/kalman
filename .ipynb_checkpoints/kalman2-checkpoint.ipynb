# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
'''
a plane is landing assume that
altitude_t = 0.98 * altitude_t-1
'''
#-----input
ALTITUDE_0 = 1000 #assume in meters

#------logic
time_t = [0]
altitude_t = [ALTITUDE_0]

for i in range(1,300+1):
    time_t.append(i)
    altitude_t.append(altitude_t[-1] * 0.98)

plt.plot(time_t, altitude_t)
plt.show()

# %%
'''
assuming our sensor has noise:
observed_t = altitude_t + noise_t
'''

#-----input
#ALTITUDE_0 = 1000 #assume in meters
NOISE = 40 #assume +/- in meters

#------logic
# time_t = [0]
# altitude_t = [ALTITUDE_0]
observed_t = []



for index, real_altitude in enumerate(altitude_t):
    observed_t.append(real_altitude + np.random.uniform(-NOISE, NOISE))

plt.plot(time_t, observed_t)
plt.show()

# %%
'''
let's now make it more generic. 
x_k = a * x_k-1 //current state = changes * previous state
z_k = x_k + v_k //observed state = current state + noise

so if the state has disturbances, we can also add process noise
x_k = a * x_k-1 + w_k //current state = changes * previous state + process noise
z_k = x_k + v_k //observed state = current state + noise
'''

def thing():
    x=1
thing()
#now no dumb outputs

# %%
'''
without process noise
x_k = a * x_k-1 
z_k = x_k + v_k

we can rearrage the 2nd equation:
x_k = z_k - noise //current state = observed state - noise


low g = noisy sensor, high g = good sensor
x_hat_k = x_hat_k-1 + g_k (z_k - x_hat_k-1)

--> our current estimated state = previous estimated state
    + gain(previous observed value - previous estimated state)
'''

#-----input
#ALTITUDE_0 = 1000 #assume in meters
#NOISE = 40 #assume +/- in meters
GAIN = 0.2 # g_k

#------logic
# time_t = [0]
# altitude_t = [ALTITUDE_0]
# observed_t = []
estimated_state_t = [ALTITUDE_0]

for i, observed in enumerate(observed_t):
    if i == 0:
        continue
    predicted = estimated_state_t[-1] + GAIN * (observed - estimated_state_t[-1])
    
    estimated_state_t.append(predicted)
    
plt.scatter(time_t, observed_t, label = "observations", s=1)
plt.plot(time_t, estimated_state_t, label = "estimation")
plt.plot(time_t, altitude_t, label = "real")
plt.show()

# %%
'''
How do we compute gain?

recall that: measurement = actual_state + noise

manufactureres will typically publish sensor error ranges
• +/- r (property of the sensor)

thus, we can compute the gain by
•g_k = p_k-1 / (p_k-1 + r)
•where p_k is prediction error and is computed recursively
    p_k = (1-g_k) * p_k-1
    current prediction error = 
        (1-gain) * previous prediction error
'''


#-----input
#ALTITUDE_0 = 1000 #assume in meters
#NOISE = 40 #assume +/- in meters

#------logic
# time_t = [0]
# altitude_t = [ALTITUDE_0]
# observed_t = []
estimated_state_t = [ALTITUDE_0] #overwrite estimated state w/ new
g_k = [1]
p_k = [10000]


r = np.average(abs(np.array(altitude_t) - np.array(observed_t)))
print(r)

for k, time in enumerate(time_t):
    if k == 0:
        continue
    
    g_k.append( p_k[k-1] / (p_k[k-1] + r) )
    p_k.append( (1-g_k[k]) * p_k[k-1]     )
    
    predicted = estimated_state_t[-1] + g_k[k] * (observed_t[k] - estimated_state_t[-1])
    
    estimated_state_t.append(predicted)

plt.scatter(time_t, observed_t, label = "observations", s=1)
plt.plot(time_t, estimated_state_t, label = "estimation")
plt.plot(time_t, altitude_t, label = "real")
plt.legend()
plt.show()

# for thing in p_k:
#     print(round(thing,2))
for i in range(0, len(g_k)):
    print( f"round: {i},  gain: {round(g_k[i],2)},  prediction error: {round(p_k[i],2)}" )
# Out:
# 19.37239512816787
# round: 0,  gain: 1,  prediction error: 10000
# round: 1,  gain: 1.0,  prediction error: 19.33
# round: 2,  gain: 0.5,  prediction error: 9.68
# round: 3,  gain: 0.33,  prediction error: 6.45
# round: 4,  gain: 0.25,  prediction error: 4.84
# round: 5,  gain: 0.2,  prediction error: 3.87
# round: 6,  gain: 0.17,  prediction error: 3.23
# round: 7,  gain: 0.14,  prediction error: 2.77
# round: 8,  gain: 0.12,  prediction error: 2.42
# round: 9,  gain: 0.11,  prediction error: 2.15
# round: 10,  gain: 0.1,  prediction error: 1.94
# round: 11,  gain: 0.09,  prediction error: 1.76
# round: 12,  gain: 0.08,  prediction error: 1.61
# round: 13,  gain: 0.08,  prediction error: 1.49
# round: 14,  gain: 0.07,  prediction error: 1.38
# round: 15,  gain: 0.07,  prediction error: 1.29
# round: 16,  gain: 0.06,  prediction error: 1.21
# round: 17,  gain: 0.06,  prediction error: 1.14
# round: 18,  gain: 0.06,  prediction error: 1.08
# round: 19,  gain: 0.05,  prediction error: 1.02
# round: 20,  gain: 0.05,  prediction error: 0.97
# round: 21,  gain: 0.05,  prediction error: 0.92
# round: 22,  gain: 0.05,  prediction error: 0.88
# round: 23,  gain: 0.04,  prediction error: 0.84
# round: 24,  gain: 0.04,  prediction error: 0.81
# round: 25,  gain: 0.04,  prediction error: 0.77
# round: 26,  gain: 0.04,  prediction error: 0.75
# round: 27,  gain: 0.04,  prediction error: 0.72
# round: 28,  gain: 0.04,  prediction error: 0.69
# round: 29,  gain: 0.03,  prediction error: 0.67
# round: 30,  gain: 0.03,  prediction error: 0.65
# round: 31,  gain: 0.03,  prediction error: 0.62
# round: 32,  gain: 0.03,  prediction error: 0.61
# round: 33,  gain: 0.03,  prediction error: 0.59
# round: 34,  gain: 0.03,  prediction error: 0.57
# round: 35,  gain: 0.03,  prediction error: 0.55
# round: 36,  gain: 0.03,  prediction error: 0.54
# round: 37,  gain: 0.03,  prediction error: 0.52
# round: 38,  gain: 0.03,  prediction error: 0.51
# round: 39,  gain: 0.03,  prediction error: 0.5
# round: 40,  gain: 0.02,  prediction error: 0.48
# round: 41,  gain: 0.02,  prediction error: 0.47
# round: 42,  gain: 0.02,  prediction error: 0.46
# round: 43,  gain: 0.02,  prediction error: 0.45
# round: 44,  gain: 0.02,  prediction error: 0.44
# round: 45,  gain: 0.02,  prediction error: 0.43
# round: 46,  gain: 0.02,  prediction error: 0.42
# round: 47,  gain: 0.02,  prediction error: 0.41
# round: 48,  gain: 0.02,  prediction error: 0.4
# round: 49,  gain: 0.02,  prediction error: 0.4
# round: 50,  gain: 0.02,  prediction error: 0.39
# round: 51,  gain: 0.02,  prediction error: 0.38
# round: 52,  gain: 0.02,  prediction error: 0.37
# round: 53,  gain: 0.02,  prediction error: 0.37
# round: 54,  gain: 0.02,  prediction error: 0.36
# round: 55,  gain: 0.02,  prediction error: 0.35
# round: 56,  gain: 0.02,  prediction error: 0.35
# round: 57,  gain: 0.02,  prediction error: 0.34
# round: 58,  gain: 0.02,  prediction error: 0.33
# round: 59,  gain: 0.02,  prediction error: 0.33
# round: 60,  gain: 0.02,  prediction error: 0.32
# round: 61,  gain: 0.02,  prediction error: 0.32
# round: 62,  gain: 0.02,  prediction error: 0.31
# round: 63,  gain: 0.02,  prediction error: 0.31
# round: 64,  gain: 0.02,  prediction error: 0.3
# round: 65,  gain: 0.02,  prediction error: 0.3
# round: 66,  gain: 0.02,  prediction error: 0.29
# round: 67,  gain: 0.01,  prediction error: 0.29
# round: 68,  gain: 0.01,  prediction error: 0.28
# round: 69,  gain: 0.01,  prediction error: 0.28
# round: 70,  gain: 0.01,  prediction error: 0.28
# round: 71,  gain: 0.01,  prediction error: 0.27
# round: 72,  gain: 0.01,  prediction error: 0.27
# round: 73,  gain: 0.01,  prediction error: 0.27
# round: 74,  gain: 0.01,  prediction error: 0.26
# round: 75,  gain: 0.01,  prediction error: 0.26
# round: 76,  gain: 0.01,  prediction error: 0.25
# round: 77,  gain: 0.01,  prediction error: 0.25
# round: 78,  gain: 0.01,  prediction error: 0.25
# round: 79,  gain: 0.01,  prediction error: 0.25
# round: 80,  gain: 0.01,  prediction error: 0.24
# round: 81,  gain: 0.01,  prediction error: 0.24
# round: 82,  gain: 0.01,  prediction error: 0.24
# round: 83,  gain: 0.01,  prediction error: 0.23
# round: 84,  gain: 0.01,  prediction error: 0.23
# round: 85,  gain: 0.01,  prediction error: 0.23
# round: 86,  gain: 0.01,  prediction error: 0.23
# round: 87,  gain: 0.01,  prediction error: 0.22
# round: 88,  gain: 0.01,  prediction error: 0.22
# round: 89,  gain: 0.01,  prediction error: 0.22
# round: 90,  gain: 0.01,  prediction error: 0.22
# round: 91,  gain: 0.01,  prediction error: 0.21
# round: 92,  gain: 0.01,  prediction error: 0.21
# round: 93,  gain: 0.01,  prediction error: 0.21
# round: 94,  gain: 0.01,  prediction error: 0.21
# round: 95,  gain: 0.01,  prediction error: 0.2
# round: 96,  gain: 0.01,  prediction error: 0.2
# round: 97,  gain: 0.01,  prediction error: 0.2
# round: 98,  gain: 0.01,  prediction error: 0.2
# round: 99,  gain: 0.01,  prediction error: 0.2
# round: 100,  gain: 0.01,  prediction error: 0.19
# round: 101,  gain: 0.01,  prediction error: 0.19
# round: 102,  gain: 0.01,  prediction error: 0.19
# round: 103,  gain: 0.01,  prediction error: 0.19
# round: 104,  gain: 0.01,  prediction error: 0.19
# round: 105,  gain: 0.01,  prediction error: 0.18
# round: 106,  gain: 0.01,  prediction error: 0.18
# round: 107,  gain: 0.01,  prediction error: 0.18
# round: 108,  gain: 0.01,  prediction error: 0.18
# round: 109,  gain: 0.01,  prediction error: 0.18
# round: 110,  gain: 0.01,  prediction error: 0.18
# round: 111,  gain: 0.01,  prediction error: 0.17
# round: 112,  gain: 0.01,  prediction error: 0.17
# round: 113,  gain: 0.01,  prediction error: 0.17
# round: 114,  gain: 0.01,  prediction error: 0.17
# round: 115,  gain: 0.01,  prediction error: 0.17
# round: 116,  gain: 0.01,  prediction error: 0.17
# round: 117,  gain: 0.01,  prediction error: 0.17
# round: 118,  gain: 0.01,  prediction error: 0.16
# round: 119,  gain: 0.01,  prediction error: 0.16
# round: 120,  gain: 0.01,  prediction error: 0.16
# round: 121,  gain: 0.01,  prediction error: 0.16
# round: 122,  gain: 0.01,  prediction error: 0.16
# round: 123,  gain: 0.01,  prediction error: 0.16
# round: 124,  gain: 0.01,  prediction error: 0.16
# round: 125,  gain: 0.01,  prediction error: 0.15
# round: 126,  gain: 0.01,  prediction error: 0.15
# round: 127,  gain: 0.01,  prediction error: 0.15
# round: 128,  gain: 0.01,  prediction error: 0.15
# round: 129,  gain: 0.01,  prediction error: 0.15
# round: 130,  gain: 0.01,  prediction error: 0.15
# round: 131,  gain: 0.01,  prediction error: 0.15
# round: 132,  gain: 0.01,  prediction error: 0.15
# round: 133,  gain: 0.01,  prediction error: 0.15
# round: 134,  gain: 0.01,  prediction error: 0.14
# round: 135,  gain: 0.01,  prediction error: 0.14
# round: 136,  gain: 0.01,  prediction error: 0.14
# round: 137,  gain: 0.01,  prediction error: 0.14
# round: 138,  gain: 0.01,  prediction error: 0.14
# round: 139,  gain: 0.01,  prediction error: 0.14
# round: 140,  gain: 0.01,  prediction error: 0.14
# round: 141,  gain: 0.01,  prediction error: 0.14
# round: 142,  gain: 0.01,  prediction error: 0.14
# round: 143,  gain: 0.01,  prediction error: 0.14
# round: 144,  gain: 0.01,  prediction error: 0.13
# round: 145,  gain: 0.01,  prediction error: 0.13
# round: 146,  gain: 0.01,  prediction error: 0.13
# round: 147,  gain: 0.01,  prediction error: 0.13
# round: 148,  gain: 0.01,  prediction error: 0.13
# round: 149,  gain: 0.01,  prediction error: 0.13
# round: 150,  gain: 0.01,  prediction error: 0.13
# round: 151,  gain: 0.01,  prediction error: 0.13
# round: 152,  gain: 0.01,  prediction error: 0.13
# round: 153,  gain: 0.01,  prediction error: 0.13
# round: 154,  gain: 0.01,  prediction error: 0.13
# round: 155,  gain: 0.01,  prediction error: 0.12
# round: 156,  gain: 0.01,  prediction error: 0.12
# round: 157,  gain: 0.01,  prediction error: 0.12
# round: 158,  gain: 0.01,  prediction error: 0.12
# round: 159,  gain: 0.01,  prediction error: 0.12
# round: 160,  gain: 0.01,  prediction error: 0.12
# round: 161,  gain: 0.01,  prediction error: 0.12
# round: 162,  gain: 0.01,  prediction error: 0.12
# round: 163,  gain: 0.01,  prediction error: 0.12
# round: 164,  gain: 0.01,  prediction error: 0.12
# round: 165,  gain: 0.01,  prediction error: 0.12
# round: 166,  gain: 0.01,  prediction error: 0.12
# round: 167,  gain: 0.01,  prediction error: 0.12
# round: 168,  gain: 0.01,  prediction error: 0.12
# round: 169,  gain: 0.01,  prediction error: 0.11
# round: 170,  gain: 0.01,  prediction error: 0.11
# round: 171,  gain: 0.01,  prediction error: 0.11
# round: 172,  gain: 0.01,  prediction error: 0.11
# round: 173,  gain: 0.01,  prediction error: 0.11
# round: 174,  gain: 0.01,  prediction error: 0.11
# round: 175,  gain: 0.01,  prediction error: 0.11
# round: 176,  gain: 0.01,  prediction error: 0.11
# round: 177,  gain: 0.01,  prediction error: 0.11
# round: 178,  gain: 0.01,  prediction error: 0.11
# round: 179,  gain: 0.01,  prediction error: 0.11
# round: 180,  gain: 0.01,  prediction error: 0.11
# round: 181,  gain: 0.01,  prediction error: 0.11
# round: 182,  gain: 0.01,  prediction error: 0.11
# round: 183,  gain: 0.01,  prediction error: 0.11
# round: 184,  gain: 0.01,  prediction error: 0.11
# round: 185,  gain: 0.01,  prediction error: 0.1
# round: 186,  gain: 0.01,  prediction error: 0.1
# round: 187,  gain: 0.01,  prediction error: 0.1
# round: 188,  gain: 0.01,  prediction error: 0.1
# round: 189,  gain: 0.01,  prediction error: 0.1
# round: 190,  gain: 0.01,  prediction error: 0.1
# round: 191,  gain: 0.01,  prediction error: 0.1
# round: 192,  gain: 0.01,  prediction error: 0.1
# round: 193,  gain: 0.01,  prediction error: 0.1
# round: 194,  gain: 0.01,  prediction error: 0.1
# round: 195,  gain: 0.01,  prediction error: 0.1
# round: 196,  gain: 0.01,  prediction error: 0.1
# round: 197,  gain: 0.01,  prediction error: 0.1
# round: 198,  gain: 0.01,  prediction error: 0.1
# round: 199,  gain: 0.01,  prediction error: 0.1
# round: 200,  gain: 0.0,  prediction error: 0.1
# round: 201,  gain: 0.0,  prediction error: 0.1
# round: 202,  gain: 0.0,  prediction error: 0.1
# round: 203,  gain: 0.0,  prediction error: 0.1
# round: 204,  gain: 0.0,  prediction error: 0.09
# round: 205,  gain: 0.0,  prediction error: 0.09
# round: 206,  gain: 0.0,  prediction error: 0.09
# round: 207,  gain: 0.0,  prediction error: 0.09
# round: 208,  gain: 0.0,  prediction error: 0.09
# round: 209,  gain: 0.0,  prediction error: 0.09
# round: 210,  gain: 0.0,  prediction error: 0.09
# round: 211,  gain: 0.0,  prediction error: 0.09
# round: 212,  gain: 0.0,  prediction error: 0.09
# round: 213,  gain: 0.0,  prediction error: 0.09
# round: 214,  gain: 0.0,  prediction error: 0.09
# round: 215,  gain: 0.0,  prediction error: 0.09
# round: 216,  gain: 0.0,  prediction error: 0.09
# round: 217,  gain: 0.0,  prediction error: 0.09
# round: 218,  gain: 0.0,  prediction error: 0.09
# round: 219,  gain: 0.0,  prediction error: 0.09
# round: 220,  gain: 0.0,  prediction error: 0.09
# round: 221,  gain: 0.0,  prediction error: 0.09
# round: 222,  gain: 0.0,  prediction error: 0.09
# round: 223,  gain: 0.0,  prediction error: 0.09
# round: 224,  gain: 0.0,  prediction error: 0.09
# round: 225,  gain: 0.0,  prediction error: 0.09
# round: 226,  gain: 0.0,  prediction error: 0.09
# round: 227,  gain: 0.0,  prediction error: 0.09
# round: 228,  gain: 0.0,  prediction error: 0.08
# round: 229,  gain: 0.0,  prediction error: 0.08
# round: 230,  gain: 0.0,  prediction error: 0.08
# round: 231,  gain: 0.0,  prediction error: 0.08
# round: 232,  gain: 0.0,  prediction error: 0.08
# round: 233,  gain: 0.0,  prediction error: 0.08
# round: 234,  gain: 0.0,  prediction error: 0.08
# round: 235,  gain: 0.0,  prediction error: 0.08
# round: 236,  gain: 0.0,  prediction error: 0.08
# round: 237,  gain: 0.0,  prediction error: 0.08
# round: 238,  gain: 0.0,  prediction error: 0.08
# round: 239,  gain: 0.0,  prediction error: 0.08
# round: 240,  gain: 0.0,  prediction error: 0.08
# round: 241,  gain: 0.0,  prediction error: 0.08
# round: 242,  gain: 0.0,  prediction error: 0.08
# round: 243,  gain: 0.0,  prediction error: 0.08
# round: 244,  gain: 0.0,  prediction error: 0.08
# round: 245,  gain: 0.0,  prediction error: 0.08
# round: 246,  gain: 0.0,  prediction error: 0.08
# round: 247,  gain: 0.0,  prediction error: 0.08
# round: 248,  gain: 0.0,  prediction error: 0.08
# round: 249,  gain: 0.0,  prediction error: 0.08
# round: 250,  gain: 0.0,  prediction error: 0.08
# round: 251,  gain: 0.0,  prediction error: 0.08
# round: 252,  gain: 0.0,  prediction error: 0.08
# round: 253,  gain: 0.0,  prediction error: 0.08
# round: 254,  gain: 0.0,  prediction error: 0.08
# round: 255,  gain: 0.0,  prediction error: 0.08
# round: 256,  gain: 0.0,  prediction error: 0.08
# round: 257,  gain: 0.0,  prediction error: 0.08
# round: 258,  gain: 0.0,  prediction error: 0.08
# round: 259,  gain: 0.0,  prediction error: 0.07
# round: 260,  gain: 0.0,  prediction error: 0.07
# round: 261,  gain: 0.0,  prediction error: 0.07
# round: 262,  gain: 0.0,  prediction error: 0.07
# round: 263,  gain: 0.0,  prediction error: 0.07
# round: 264,  gain: 0.0,  prediction error: 0.07
# round: 265,  gain: 0.0,  prediction error: 0.07
# round: 266,  gain: 0.0,  prediction error: 0.07
# round: 267,  gain: 0.0,  prediction error: 0.07
# round: 268,  gain: 0.0,  prediction error: 0.07
# round: 269,  gain: 0.0,  prediction error: 0.07
# round: 270,  gain: 0.0,  prediction error: 0.07
# round: 271,  gain: 0.0,  prediction error: 0.07
# round: 272,  gain: 0.0,  prediction error: 0.07
# round: 273,  gain: 0.0,  prediction error: 0.07
# round: 274,  gain: 0.0,  prediction error: 0.07
# round: 275,  gain: 0.0,  prediction error: 0.07
# round: 276,  gain: 0.0,  prediction error: 0.07
# round: 277,  gain: 0.0,  prediction error: 0.07
# round: 278,  gain: 0.0,  prediction error: 0.07
# round: 279,  gain: 0.0,  prediction error: 0.07
# round: 280,  gain: 0.0,  prediction error: 0.07
# round: 281,  gain: 0.0,  prediction error: 0.07
# round: 282,  gain: 0.0,  prediction error: 0.07
# round: 283,  gain: 0.0,  prediction error: 0.07
# round: 284,  gain: 0.0,  prediction error: 0.07
# round: 285,  gain: 0.0,  prediction error: 0.07
# round: 286,  gain: 0.0,  prediction error: 0.07
# round: 287,  gain: 0.0,  prediction error: 0.07
# round: 288,  gain: 0.0,  prediction error: 0.07
# round: 289,  gain: 0.0,  prediction error: 0.07
# round: 290,  gain: 0.0,  prediction error: 0.07
# round: 291,  gain: 0.0,  prediction error: 0.07
# round: 292,  gain: 0.0,  prediction error: 0.07
# round: 293,  gain: 0.0,  prediction error: 0.07
# round: 294,  gain: 0.0,  prediction error: 0.07
# round: 295,  gain: 0.0,  prediction error: 0.07
# round: 296,  gain: 0.0,  prediction error: 0.07
# round: 297,  gain: 0.0,  prediction error: 0.07
# round: 298,  gain: 0.0,  prediction error: 0.07
# round: 299,  gain: 0.0,  prediction error: 0.06
# round: 300,  gain: 0.0,  prediction error: 0.06

# %%
'''
kalman filter in a nutshell

predict:
x_hat_k = a * x_hat_k-1

p_k = a * p_k-1 * a

update:
g_k = p_k-1 / (p_k-1 + r)
x_hat_k = x_hat_k + g_k (z_k - x_hat_k)
p_k = (1-g_k) p_k

z_k = x_k + v_k

'''

NOISE = 0
r = NOISE + 0.0000000000000000001
a = 0.90

#at k=0
x_k = 1000
z_k = 930
p_k = 1
x_hat_k = 930
g_k= 0
z_k = x_k + np.random.uniform(-NOISE, NOISE)





log = [[0, x_k, z_k, p_k, x_hat_k, g_k]]

for i in range(1,12):
    #motion
    x_k = a * x_k
    
    
    #predict
    
    x_hat_k = a * x_hat_k
    p_k = a * p_k * a 
    
    
    #sense
    z_k = x_k + np.random.uniform(-NOISE, NOISE)
    
    #update
    
    
    g_k = p_k / (p_k + r)
    x_hat_k = x_hat_k + g_k * (z_k - x_hat_k)
    p_k = (1-g_k) * p_k
    
    log.append([i, x_k, z_k, p_k, x_hat_k, g_k])


#print(log)
#plt.scatter(time_t, observed_t, label = "observations", s=1)
plt.plot([ i[0] for i in log], [ i[1] for i in log], label = "true state")
plt.plot([ i[0] for i in log], [ i[2] for i in log], label = "measured state")
plt.plot([ i[0] for i in log], [ i[4] for i in log], label = "estimated state")
#plt.plot(time_t, altitude_t, label = "real")
plt.legend()
plt.show()



#-----input
#ALTITUDE_0 = 1000 #assume in meters
#NOISE = 40 #assume +/- in meters

#------logic
# time_t = [0]
# altitude_t = [ALTITUDE_0]
# observed_t = []
# estimated_state_t = [ALTITUDE_0] #overwrite estimated state w/ new
# g_k = [1]
# p_k = [10000]




for i in log:
    print(f"true: {round(i[1],2)},  estimated: {round(i[4],2)}, prediction error: {round(i[3],2)}")

true_state = [i[1] for i in log]
estimated_state = [i[4] for i in log]


#print(np.average(abs(np.array(true_state) - np.array(estimated_state))))
# Out:
# true: 1000,  estimated: 930, prediction error: 1
# true: 900.0,  estimated: 900.0, prediction error: 0.0
# true: 810.0,  estimated: 810.0, prediction error: 0.0
# true: 729.0,  estimated: 729.0, prediction error: 0.0
# true: 656.1,  estimated: 656.1, prediction error: 0.0
# true: 590.49,  estimated: 590.49, prediction error: 0.0
# true: 531.44,  estimated: 531.44, prediction error: 0.0
# true: 478.3,  estimated: 478.3, prediction error: 0.0
# true: 430.47,  estimated: 430.47, prediction error: 0.0
# true: 387.42,  estimated: 387.42, prediction error: 0.0
# true: 348.68,  estimated: 348.68, prediction error: 0.0
# true: 313.81,  estimated: 313.81, prediction error: 0.0

# %%
#TODO: Comeback and tackle part 9 when our brains are bigger.

'''
kalman filter in a nutshell

predict:
x_hat_k = a * x_hat_k-1 + b * u_k
p_k = a * p_k-1 * a


update:
g_k = p_k-1 * c / (c* p_k-1 * c + r)
x_hat_k = x_hat_k + g_k (z_k - c* x_hat_k)
p_k = (1-g_k * c) p_k

z_k = x_k + v_k

'''

NOISE = 0
r = NOISE + 0.0000000000000000001
a = 0.90
b = 0.1
c = 0.1

#at k=0
x_k = 1000
z_k = 930
p_k = 1
x_hat_k = 930
g_k= 0
z_k = x_k + np.random.uniform(-NOISE, NOISE)







log = [[0, x_k, z_k, p_k, x_hat_k, g_k]]

for i in range(1,12):
    #motion
    #x_k = a * x_k + 
    
    
    #predict
    
    x_hat_k = a * x_hat_k
    p_k = a * p_k * a 
    
    
    #sense
    z_k = x_k + np.random.uniform(-NOISE, NOISE)
    
    #update
    
    
    g_k = p_k / (p_k + r)
    x_hat_k = x_hat_k + g_k * (z_k - x_hat_k)
    p_k = (1-g_k) * p_k
    
    log.append([i, x_k, z_k, p_k, x_hat_k, g_k])


#print(log)
#plt.scatter(time_t, observed_t, label = "observations", s=1)
plt.plot([ i[0] for i in log], [ i[1] for i in log], label = "true state")
plt.plot([ i[0] for i in log], [ i[2] for i in log], label = "measured state")
plt.plot([ i[0] for i in log], [ i[4] for i in log], label = "estimated state")
#plt.plot(time_t, altitude_t, label = "real")
plt.legend()
plt.show()



#-----input
#ALTITUDE_0 = 1000 #assume in meters
#NOISE = 40 #assume +/- in meters

#------logic
# time_t = [0]
# altitude_t = [ALTITUDE_0]
# observed_t = []
# estimated_state_t = [ALTITUDE_0] #overwrite estimated state w/ new
# g_k = [1]
# p_k = [10000]




for i in log:
    print(f"true: {round(i[1],2)},  estimated: {round(i[4],2)}, prediction error: {round(i[3],2)}")

true_state = [i[1] for i in log]
estimated_state = [i[4] for i in log]


#print(np.average(abs(np.array(true_state) - np.array(estimated_state))))
# Out:
# true: 1000,  estimated: 930, prediction error: 1
# true: 1000,  estimated: 1000.0, prediction error: 0.0
# true: 1000,  estimated: 900.0, prediction error: 0.0
# true: 1000,  estimated: 810.0, prediction error: 0.0
# true: 1000,  estimated: 729.0, prediction error: 0.0
# true: 1000,  estimated: 656.1, prediction error: 0.0
# true: 1000,  estimated: 590.49, prediction error: 0.0
# true: 1000,  estimated: 531.44, prediction error: 0.0
# true: 1000,  estimated: 478.3, prediction error: 0.0
# true: 1000,  estimated: 430.47, prediction error: 0.0
# true: 1000,  estimated: 387.42, prediction error: 0.0
# true: 1000,  estimated: 348.68, prediction error: 0.0

# %%
import matplotlib.image as mpimg

'''
so if we bring physics into the equation
distance_current = distance_previous + v * timestep

it's time for linear algebraaaaaaaaaaaaaaaaaaa

if
[a b] * [x] = [ax + by]
[c d]   [y]   [cx + by]

x_k = [ distance_k ]
      [ velocity_k ]
      

A = [1 timestep]       
    [0 1       ]
    
A * x_k-1 = **look at image below**
'''

img = mpimg.imread('shot1.png')
plt.imshow(img)

# %%
img = mpimg.imread('shot2')
plt.imshow(img)

# %%
'''
part 12

now we know that
x_k = A * x_k-1
x_k = a * x_l-1 + b * u_k
z_k = c * x_k + v_k

but we don't know what B and C are.

'''
from matplotlib.pyplot import figure

figure(num=None, figsize=(12, 9), dpi=100, facecolor='w', edgecolor='k')

img = mpimg.imread('shot3.png')
plt.imshow(img)

# %%
'''
what is transposing? gee that's a grate question
rows --> c
c --> rows
'''

matrix_A = np.matrix('1 2; 3 4')
matrix_A_transposed = np.transpose(matrix_A)

print(matrix_A)
print(matrix_A_transposed)
# Out:
# [[1 2]
#  [3 4]]
# [[1 3]
#  [2 4]]

# %%
figure(num=None, figsize=(12, 9), dpi=100, facecolor='w', edgecolor='k')

img = mpimg.imread('shot4.png')
plt.imshow(img)

# %%
##14.....
import math

x = [0]
y = [0]
vel = [0]

y_sensor1 = [0]
y_sensor2 = [0]

y_estimate = [0]


process_noise = 0.03
sensor_noise = 21093718.04

sensor1_bias = 1
sensor2_bias = 1

for degree in range(1,720):
    radian = degree * math.pi / 180
    
    #action
    true_x = radian
    true_y = math.sin(radian) + np.random.uniform(-process_noise, process_noise)
    x.append(true_x)
    y.append(true_y)
    
    sensor1 = true_y + np.random.uniform(-process_noise, process_noise) + sensor1_bias
    sensor2 = true_y + np.random.uniform(-process_noise, process_noise) + sensor2_bias
    y_sensor1.append(sensor1)
    y_sensor2.append(sensor2)
    
    
    
    true_vel_1 = (y_sensor1[degree] - y_sensor1[degree-1]) / 1
    true_vel_2 = (y_sensor2[degree] - y_sensor2[degree-1]) / 1
    
    true_vel = (true_vel_1 + true_vel_2) / 2
    vel.append(true_vel)
    
    
   
    
    #predict
    A = np.matrix('1 1; 0 1')
    x_hat_k_prev = np.matrix(f'{y[degree]} ; {true_vel}' ) 
    
    #x_k = A * x_k-1
    x_hat_k = A * x_hat_k_prev
    
    #print(x_hat_k)
    y_estimate.append(x_hat_k[0][0])
    
    #x_k_hat = 
    
    
    
    
    
    
#print(log)
#plt.scatter(time_t, observed_t, label = "observations", s=1)
plt.plot(x, y, label = "true state")
plt.scatter(x, y_sensor1, s=0.1, label = "sensor1")
plt.scatter(x, y_sensor2, s=0.1, label = "sensor2")
plt.plot(x, y_estimate, label = "linear approx")
# plt.plot([ i[0] for i in log], [ i[4] for i in log], label = "estimated state")
# #plt.plot(time_t, altitude_t, label = "real")
plt.legend()
plt.show()


print(np.average(abs((np.array(y) - np.array(y_estimate)))) )
# Out:
# [[0.02754628]]
